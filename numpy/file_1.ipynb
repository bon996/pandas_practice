# %%
import numpy as np

# %%
a = np.array([1,3,5])
a
# Out:
# array([1, 3, 5])

# %%
a[1]
# Out:
# np.int64(3)

# %%
import time
import sys

# %%
list = range(1000)
print(sys.getsizeof(5)*len(list))
# Out:
# 28000

# %%
array = np.arange(1000)
print(array.size*array.itemsize)
# Out:
# 8000
