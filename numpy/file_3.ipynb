# %%
import numpy as np

# %%
np.zeros(2)
# Out:
# array([0., 0.])

# %%
np.ones([2,4])
# Out:
# array([[1., 1., 1., 1.],
#        [1., 1., 1., 1.]])

# %%
np.empty(2)
# Out:
# array([0., 0.])

# %%
np.arange(4)
# Out:
# array([0, 1, 2, 3])

# %%
np.arange(2,12,3)
# Out:
# array([ 2,  5,  8, 11])

# %%
np.linspace(0,10,num=5)
# Out:
# array([ 0. ,  2.5,  5. ,  7.5, 10. ])

# %%
x = np.ones(2, dtype=np.int64)

# %%
x
# Out:
# array([1, 1])
