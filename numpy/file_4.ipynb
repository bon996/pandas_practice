# %%
import numpy as np
import pandas as pd

# %%
a = np.array([1,2,3,4,5,6])
a.shape
# Out:
# (6,)

# %%
a2 = a[np.newaxis, :]
a2.shape
# Out:
# (1, 6)

# %%
row_vector = a[np.newaxis, : ]
row_vector.shape
# Out:
# (1, 6)

# %%
col_vector = a[: , np.newaxis]

# %%
col_vector
# Out:
# array([[1],
#        [2],
#        [3],
#        [4],
#        [5],
#        [6]])

# %%
a
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
b = np.expand_dims(a,axis=1)
b.shape
# Out:
# (6, 1)
