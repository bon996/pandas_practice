# %%
import numpy as np

# %%
a = np.array([1,3,4,6])

# %%
a
# Out:
# array([1, 3, 4, 6])

# %%
b = np.array([[3,5,6,8],[4,3,6,2],[6,3,1,4]])
b
# Out:
# array([[3, 5, 6, 8],
#        [4, 3, 6, 2],
#        [6, 3, 1, 4]])

# %%
b.ndim
# Out:
# 2

# %%
b.shape
# Out:
# (3, 4)

# %%
len(b.shape) == b.ndim
# Out:
# True

# %%
b.size
# Out:
# 12

# %%
import math

# %%
b.size == math.prod(b.shape)
# Out:
# True

# %%
b.dtype
# Out:
# dtype('int64')
