# %%
import numpy as np

# %%
arr = np.array([2,4,5,2,4,5,2,4,3])
arr
# Out:
# array([2, 4, 5, 2, 4, 5, 2, 4, 3])

# %%
np.sort(arr)
# Out:
# array([2, 2, 2, 3, 4, 4, 4, 5, 5])

# %%
np.argsort(arr)
# Out:
# array([0, 3, 6, 8, 1, 4, 7, 2, 5])

# %%
a = np.array([1, 2, 3, 4])
b = np.array([5, 6, 7, 8])

# %%
np.concatenate((a,b))
# Out:
# array([1, 2, 3, 4, 5, 6, 7, 8])

# %%
array_example = np.array([[[0, 1, 2, 3],
                           [4, 5, 6, 7]],

                          [[0, 1, 2, 3],
                           [4, 5, 6, 7]],

                          [[0 ,1 ,2, 3],
                           [4, 5, 6, 7]]])

# %%
array_example
# Out:
# array([[[0, 1, 2, 3],
#         [4, 5, 6, 7]],
#
#        [[0, 1, 2, 3],
#         [4, 5, 6, 7]],
#
#        [[0, 1, 2, 3],
#         [4, 5, 6, 7]]])

# %%
array_example.ndim
# Out:
# 3

# %%
array_example.size
# Out:
# 24

# %%
array_example.shape
# Out:
# (3, 2, 4)

# %%
arr.reshape(3,3)
# Out:
# array([[2, 4, 5],
#        [2, 4, 5],
#        [2, 4, 3]])
